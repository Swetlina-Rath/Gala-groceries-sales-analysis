# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/swetl/Downloads/sample_sales_data.csv')

# %%
df
# Out:
#       Unnamed: 0                        transaction_id            timestamp  \
# 0              0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1              1  931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2              2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3              3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4              4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
# ...          ...                                   ...                  ...
# 7824        7824  6c19b9fc-f86d-4526-9dfe-d8027a4d13ee  2022-03-03 18:22:09
# 7825        7825  1c69824b-e399-4b79-a5e7-04a3a7db0681  2022-03-04 19:14:46
# 7826        7826  79aee7d6-1405-4345-9a15-92541e9e1e74  2022-03-03 14:00:09
# 7827        7827  e5cc4f88-e5b7-4ad5-bc1b-12a828a14f55  2022-03-04 15:11:38
# 7828        7828  afd70b4f-ee21-402d-8d8f-0d9e13c2bea6  2022-03-06 13:50:36
#
# ...

# %%
df.shape
# Out:
# (7829, 10)

# %%
df.head()
# Out:
#    Unnamed: 0                        transaction_id            timestamp  \
# 0           0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1           1  931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2           2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3           3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4           4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# 2  7c55cbd4-f306-4c04-a030-628cbe7867c1    fruit       premium        0.19
# 3  80da8348-1707-403f-8be7-9e6deeccc883    fruit          gold        0.19
# 4  7f5e86e6-f06f-45f6-bf44-27b095c9ad1d    fruit         basic        4.49
#
#    quantity  total payment_type
# 0         2   7.98     e-wallet
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7829 entries, 0 to 7828
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      7829 non-null   int64
#  1   transaction_id  7829 non-null   object
#  2   timestamp       7829 non-null   object
#  3   product_id      7829 non-null   object
#  4   category        7829 non-null   object
#  5   customer_type   7829 non-null   object
#  6   unit_price      7829 non-null   float64
#  7   quantity        7829 non-null   int64
#  8   total           7829 non-null   float64
#  9   payment_type    7829 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 611.8+ KB

# %%
pd.isnull(df).sum()
# Out:
# Unnamed: 0        0
# transaction_id    0
# timestamp         0
# product_id        0
# category          0
# customer_type     0
# unit_price        0
# quantity          0
# total             0
# payment_type      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'transaction_id', 'timestamp', 'product_id', 'category',
#        'customer_type', 'unit_price', 'quantity', 'total', 'payment_type'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Unnamed: 0   unit_price     quantity        total
# count  7829.000000  7829.000000  7829.000000  7829.000000
# mean   3914.000000     7.819480     2.501597    19.709905
# std    2260.181962     5.388088     1.122722    17.446680
# min       0.000000     0.190000     1.000000     0.190000
# 25%    1957.000000     3.990000     1.000000     6.570000
# 50%    3914.000000     7.190000     3.000000    14.970000
# 75%    5871.000000    11.190000     4.000000    28.470000
# max    7828.000000    23.990000     4.000000    95.960000

# %%
sales_by_category = df.groupby('category')['total'].sum()
plt.bar(sales_by_category.index, sales_by_category.values)
plt.xlabel('Product Category')
plt.ylabel('Total Sales Amount')
plt.title('Total Sales Amount by Product Category')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# most of the cells are from kitchen category.

# %%
df['timestamp'] = df['timestamp'].astype('datetime64[ns]')

# %%
df['timestamp'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['date_only'] = df['timestamp'].dt.date.astype('datetime64[ns]')

# %%
df.head()
# Out:
#    Unnamed: 0                        transaction_id           timestamp  \
# 0           0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed 2022-03-02 09:51:38
# 1           1  931ad550-09e8-4da6-beaa-8c9d17be9c60 2022-03-06 10:33:59
# 2           2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea 2022-03-04 17:20:21
# 3           3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4 2022-03-02 17:23:58
# 4           4  a81a6cd3-5e0c-44a2-826c-aea43e46c514 2022-03-05 14:32:43
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# 2  7c55cbd4-f306-4c04-a030-628cbe7867c1    fruit       premium        0.19
# 3  80da8348-1707-403f-8be7-9e6deeccc883    fruit          gold        0.19
# 4  7f5e86e6-f06f-45f6-bf44-27b095c9ad1d    fruit         basic        4.49
#
#    quantity  total payment_type  date_only
# ...

# %%
df['Date'] = pd.to_datetime(df['date_only'])
sales_over_time = df.groupby('date_only')['total'].sum()
plt.plot(sales_over_time.index, sales_over_time.values)
plt.xlabel('Date')
plt.ylabel('Total Sales Amount')
plt.title('Sales Trend over Time')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# maximum sales have taken place on 3rd february, 2022.

# %%
# bar chart of category
ax = sns.countplot(x = 'category',data = df)

for bars in ax.containers:
    ax.bar_label(bars)
    sns.set(rc={'figure.figsize':(38,5)})

# %% [markdown]
# fruits are sold in most quantity.

# %%
sales_cat = df.groupby(['category'], as_index=False)['quantity'].sum().sort_values(by='quantity', ascending=False)

sns.barplot(x = 'category',y= 'quantity' ,data = sales_cat)
# Out:
# <Axes: xlabel='category', ylabel='quantity'>

# %%
From the above graphs we can see that most of the buyers buy fruits and even the quantity of fruits bought is highest among all.
# Out:
#   Cell In[97], line 1
#     From the above graphs we can see that most of the buyers buy fruits and even the quantity of fruits bought is highest among all.
#          ^
# SyntaxError: invalid syntax

# %%
sales_cus = df.groupby(['customer_type'], as_index=False)['quantity'].sum().sort_values(by='customer_type', ascending=False)
sns.set(rc={'figure.figsize':(5,5)})
sns.barplot(x = 'customer_type',y= 'quantity' ,data = sales_cus )
# Out:
# <Axes: xlabel='customer_type', ylabel='quantity'>

# %%
most quantity of products has been brought by standard customer type.
# Out:
#   Cell In[99], line 1
#     most quantity of products has been brought by standard customer type.
#          ^
# SyntaxError: invalid syntax

# %%
sales_pri = df.groupby(['category'], as_index=False)['unit_price'].sum().sort_values(by='unit_price', ascending=False)
sns.set(rc={'figure.figsize':(30,5)})
sns.barplot(x = 'category',y= 'unit_price' ,data = sales_pri )
# Out:
# <Axes: xlabel='category', ylabel='unit_price'>

# %%
the unit price of kitchen is more than that of all categories.
# Out:
#   Cell In[101], line 1
#     the unit price of kitchen is more than that of all categories.
#         ^
# SyntaxError: invalid syntax

# %%
sales_tot = df.groupby(['customer_type'], as_index=False)['total'].sum().sort_values(by='total', ascending=False)
sns.set(rc={'figure.figsize':(10,5)})
sns.barplot(x = 'customer_type',y= 'total' ,data = sales_tot )
# Out:
# <Axes: xlabel='customer_type', ylabel='total'>

# %%
from the above graph it can be concluded that non members spend most money in buying the products.
# Out:
#   Cell In[103], line 1
#     from the above graph it can be concluded that non members spend most money in buying the products.
#              ^
# SyntaxError: invalid syntax

# %%
sales_pay = df.groupby(['payment_type'], as_index=False)['total'].sum().sort_values(by='total', ascending=False)
sns.set(rc={'figure.figsize':(10,5)})
sns.barplot(x = 'payment_type',y= 'total' ,data = sales_pay )
# Out:
# <Axes: xlabel='payment_type', ylabel='total'>

# %%
it can be clear that most of the payments are done using cash
# Out:
#   Cell In[105], line 1
#     it can be clear that most of the payments are done using cash
#        ^
# SyntaxError: invalid syntax

# %%
df['customer_type'] = df['customer_type'].astype(str)

# %%
plt.figure(figsize=(38, 10))
sns.countplot(x='category', hue='customer_type',data=df)

# Add title and labels
plt.title('Number of Sales by Customer Type and Category')
plt.xlabel('category')
plt.ylabel('count')
plt.legend(title='customer type')

# Show the plot
plt.show()

# %% [markdown]
# from the above observation its clear that most of the standard customer type spend on buying fruits.

# %%
df['payment_type'] = df['payment_type'].astype(str)

# %%
plt.figure(figsize=(38, 10))
sns.countplot(x='customer_type', hue='payment_type',data=df)

# Add title and labels
plt.title('Type of payment by various customer type')
plt.xlabel('customer_type')
plt.ylabel('payment_type')
plt.legend(title='customer type')

# Show the plot
plt.show()
